# %% [markdown]
# # Sears product catalog review - Boots

# %%
from splinter import Browser
from bs4 import BeautifulSoup 
import time
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Data Extraction

# %% [markdown]
# ### Use splinter and chromedriver to navigate/automate page actions

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
#browser = webdriver.Chrome('./chromedriver')

# %%
url = 'https://www.sears.com/shoes-women-s-shoes-women-s-boots/b-5007213'
browser.visit(url)

# %% [markdown]
# ### Scrape Sears website ( Boots product catalog) using Beautiful Soup

# %%
Bootsdata =[]
Bootsdata1=[]
# Loop through the pages of Boot shoes and parse the html to capture product name, price etc 
for x in range(1,3):
    print('Collecting page ', x, 'Shoes data')
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    time.sleep(5)

    listings= soup.find_all("div", class_="card-bottom")
    print(len(listings))
    #time.sleep(7)

    for i in range(len(listings)):
        l_0 = listings[i].find('a')
        title=l_0['title']
        fpricelist= listings[i].find("span", class_="card-price")
        Final_price=fpricelist.get_text()
        opricelist=listings[i].find("span", class_="ng-scope")
        Org_Price=opricelist.get_text()
        Bootsdata.append({'title':title,
                         'final_price':Final_price,
                         'org_price':Org_Price})
    time.sleep(30)
    button = 'NEXT'
    browser.find_by_text(button).click()
    #time.sleep(3)
    Bootsdata
# Out:
# ...
# 6
# ...
# 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-ae0da4835dda> in <module>
#      23                          'final_price':Final_price,
#      24                          'org_price':Org_Price})
# ---> 25     time.sleep(30)
#      26     button = 'NEXT'
#      27     browser.find_by_text(button).click()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Ignore this code

# %%
# 
Bootsdata =[]
Bootsdata1=[]
listing=[]
page = 2
# Loop through the pages of Boot shoes and parse the html to capture product name, price etc 
for x in range(1,3):
    print('Collecting page ', x, 'Shoes data')
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    time.sleep(15)
    listings= soup.find_all("div", class_="card-bottom")
    #while len(listings) > 45:
        #time.sleep(5)
    print(len(listings))
    print(listings)
    listing.append(listings)
    #break
    print(len(browser.find_by_tag('span')))
    time.sleep(30)
    if (page>1):
        url = 'https://www.sears.com/shoes-women-s-shoes-women-s-boots/b-5007213?pageNum=' + str(page)
        browser.visit(url)
        page += 1
    else:
        print('page not found')
        
#     button = 'NEXT'
#     browser.find_by_text(button).click()
# Out:
# ...
# 6
# ...

# %%
df=pd.DataFrame(Bootsdata)
df
# Out:
#                                                 title final_price org_price
# 0         I Love Comfort Women's Julia Bootie - Black      $29.99    $39.99
# 1   Simply Styled Women's Elliot Slouch Ankle Boot...      $19.99    $29.99
# 2   I Love Comfort Women's Addie Ankle Bootie - Brown      $29.99    $49.99
# 3          I Love Comfort Women's Julia Bootie - Navy      $29.99    $39.99
# 4          Roebuck & Co. Women's Portia Bootie - Gray      $19.99    $39.99
# 5   Roebuck & Co. Women's Cara Knee-High Boot - Black      $49.99    $69.99
# 6            Metaphor Women's Veda Ankle Boot - Black      $29.99    $59.99
# 7   Roebuck & Co. Women's Greta Quilted Riding Boo...      $49.99    $69.99
# 8   Roebuck & Co. Women's Jagger Moccasin Boot - B...      $39.99    $59.99
# 9    I Love Comfort Women's Leia Ankle Bootie - Black      $39.99    $49.99
# 10      I Love Comfort Women's Nova Ankle Boot - Gray      $29.99    $49.99
# ...

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ### Store data into a dataframe

# %%
boots_df=pd.DataFrame(Bootsdata)
boots_df
# Out:
#                                                  title      final_price  \
# 0          I Love Comfort Women's Julia Bootie - Black           $29.99
# 1    Simply Styled Women's Elliot Slouch Ankle Boot...           $19.99
# 2    I Love Comfort Women's Addie Ankle Bootie - Brown           $29.99
# 3           I Love Comfort Women's Julia Bootie - Navy           $29.99
# 4           Roebuck & Co. Women's Portia Bootie - Gray           $19.99
# ..                                                 ...              ...
# 992   Rock & Candy Danlea Mid-Calf Winter Boots, Brown           $40.99
# 993  Alfani Womens Vennuss Almond Toe Knee High Fas...  $31.54 - $52.98
# 994  Soda Shoes Soda Women's Daily Faux Nubuck Leat...  $22.39 - $29.95
# 995  Guess Womens Harson5 Closed Toe Knee High Fash...           $25.40
# 996     Not Rated Women's Double Dip Cream Cowboy Boot           $79.95
#
#              org_price
# 0               $39.99
# 1               $29.99
# 2               $49.99
# ...

# %% [markdown]
# ### create new columns title and color  by splitting title column

# %%
boots_df[['product_name','color']] = boots_df.title.str.split("-",n=1,expand=True) 
boots_df
# Out:
#                                                  title      final_price  \
# 0          I Love Comfort Women's Julia Bootie - Black           $29.99
# 1    Simply Styled Women's Elliot Slouch Ankle Boot...           $19.99
# 2    I Love Comfort Women's Addie Ankle Bootie - Brown           $29.99
# 3           I Love Comfort Women's Julia Bootie - Navy           $29.99
# 4           Roebuck & Co. Women's Portia Bootie - Gray           $19.99
# ..                                                 ...              ...
# 992   Rock & Candy Danlea Mid-Calf Winter Boots, Brown           $40.99
# 993  Alfani Womens Vennuss Almond Toe Knee High Fas...  $31.54 - $52.98
# 994  Soda Shoes Soda Women's Daily Faux Nubuck Leat...  $22.39 - $29.95
# 995  Guess Womens Harson5 Closed Toe Knee High Fash...           $25.40
# 996     Not Rated Women's Double Dip Cream Cowboy Boot           $79.95
#
#              org_price                                       product_name  \
# ...

# %% [markdown]
# ### Clean DataFrame

# %%
new_boots_df = boots_df[['product_name', 'color','org_price', 'final_price']].copy()
new_boots_df.index.name = 'id'
new_boots_df=new_boots_df.reset_index()
new_boots_df.head()
# Out:
#    id                                     product_name   color org_price  \
# 0   0             I Love Comfort Women's Julia Bootie    Black    $39.99
# 1   1  Simply Styled Women's Elliot Slouch Ankle Boot    Black    $29.99
# 2   2       I Love Comfort Women's Addie Ankle Bootie    Brown    $49.99
# 3   3             I Love Comfort Women's Julia Bootie     Navy    $39.99
# 4   4             Roebuck & Co. Women's Portia Bootie     Gray    $39.99
#
#   final_price
# 0      $29.99
# 1      $19.99
# 2      $29.99
# 3      $29.99
# 4      $19.99

# %%
type(new_boots_df['Final_Price'])
#new_boots_df['Final_Price'] = new_boots_df['Final_Price'].apply(lambda x: "${:.1f}k".format((x/1000)))

# %%
#new_boots_df.groupby('Color')['Org_Price'].sort()
new_boots_df.sort_values(['Final_Price']).groupby('Color').head(250)
new_boots_df
#new_boots_df.groupby('Color').sort_values(new_boots_df['Final_Price'],ascending=False).head(3)

# %% [markdown]
# # Data Load

# %% [markdown]
# ### Connect to local database

# %%
engine = create_engine('postgresql://postgres:Passc0de!@localhost:5432/ETLProject')

# %%
engine.table_names()
# Out:
# ['sears_catalog']

# %% [markdown]
# ### Use pandas to load web scraped converted DataFrame into database

# %%
new_boots_df.to_sql(name='sears_catalog', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the sears_catalog table

# %%
pd.read_sql_query('select * from sears_catalog', con=engine).head()
# Out:
#    id                                     product_name   color org_price  \
# 0   0             I Love Comfort Women's Julia Bootie    Black    $39.99
# 1   1  Simply Styled Women's Elliot Slouch Ankle Boot    Black    $29.99
# 2   2       I Love Comfort Women's Addie Ankle Bootie    Brown    $49.99
# 3   3             I Love Comfort Women's Julia Bootie     Navy    $39.99
# 4   4             Roebuck & Co. Women's Portia Bootie     Gray    $39.99
#
#   final_price
# 0      $29.99
# 1      $19.99
# 2      $29.99
# 3      $29.99
# 4      $19.99
